# %% [markdown]
# # Image recognition program that returns the brand of a shoe

# %% [markdown]
# ## Web scraping zalando

# %%
import os
from time import sleep
import numpy as np
import pandas as pd
from selenium import webdriver
from bs4 import *
import requests

# %%
path = r'C:\Users\Erik\ErikRepo\Project-Week-8-Final-Project\chromedriver.exe'

# %%
url = 'https://www.zalando.co.uk/men/?q=nike+shoes&p=1'

# %%
browser = webdriver.Chrome(path)

browser.get(url.format(1))

sleep(5)

soup = BeautifulSoup(browser.page_source,'lxml')

browser.close()

# %%
soup.contents
# Out:
# [<html class="js-focus-visible z-base-assets-major-5 z-base-assets-minor-3 z-base-assets-patch-1" data-js-focus-visible="" lang="en-GB" style="padding-bottom: 282px; height: auto; min-height: auto;"><head>
#  <meta charset="utf-8"/>
#  <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#  <script id="arL_G7jv7" src="https://app.usercentrics.eu/latest/main.js" type="text/javascript"></script><script crossorigin="" src="https://mosaic01.ztat.net/base-assets/require-2.1.22.min.js"></script>
# ...

# %%
print(soup.prettify())
# Out:
# <html class="js-focus-visible z-base-assets-major-5 z-base-assets-minor-3 z-base-assets-patch-1" data-js-focus-visible="" lang="en-GB" style="padding-bottom: 282px; height: auto; min-height: auto;">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <script id="arL_G7jv7" src="https://app.usercentrics.eu/latest/main.js" type="text/javascript">
#   </script>
#   <script crossorigin="" src="https://mosaic01.ztat.net/base-assets/require-2.1.22.min.js">
#   </script>
#   <script>
# ...

# %%
# Select each item
item_selector = soup.select('.qMZa55.SQGpu8.iOzucJ.JT3_zV.DvypSJ')

# %%
len(item_selector)
# Out:
# 84

# %%
type(item_selector)
# Out:
# bs4.element.ResultSet

# %%
# os.mkdir('shoe pics')
i = 1

# %%
# img_links

# %% [markdown]
# ### Brand name

# %%
item_selector[0].select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.uc9Eq5.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text
# Out:
# 'Nike Sportswear'

# %% [markdown]
# ### Shoe name

# %%
item_selector[0].select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text
# Out:
# "AIR FORCE 1 '07 - Trainers - black"

# %% [markdown]
# ### Shoe price

# %%
item_selector[0].select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.cMfkVL')[0].text
# Out:
# ' £74.99'

# %%
brand = []
name = []
price = []
img_links = []

# %%
len(item_selector)
# Out:
# 84

# %%
len(x)
# Out:
# 84

# %%
def url_iteration(n, range())

# %%
x = soup.select('img[src^="https://img01.ztat.net/article/spp-media-p1/"]')

for img in x:
    img_links.append(img['src'])

for index, img_link in enumerate(img_links):
    img_data = requests.get(img_link).content
    with open('shoe pics/'+str(index+1)+'.jpg', 'wb+') as f:
        f.write(img_data)

for item in item_selector:
    try:
        brand.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.uc9Eq5.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text)
        name.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text)        
        price.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.cMfkVL')[0].text)
    except:
        price.append(item.select('.u-6V88.ka2E9k.uMhVZi.dgII7d.z-oVg8._88STHx.cMfkVL')[0].text)

# %%
brand
# Out:
# ['Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike SB',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike SB',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike SB',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Performance',
#  'Nike Sportswear',
#  'Nike Sportswear',
#  'Nike Sportswear',
# ...

# %%
price
# Out:
# [' £74.99',
#  ' £77.99',
#  ' £79.99',
#  ' £65.00',
#  ' £89.99',
#  ' £129.99',
#  ' £114.99',
#  ' £65.00',
#  ' £52.49',
#  ' £65.00',
#  ' £47.99',
#  ' £114.99',
#  ' £79.99',
#  ' £22.99',
#  ' £112.49',
#  ' £77.99',
#  ' £47.99',
#  ' £140.24',
#  ' £23.99',
#  ' £62.99',
#  ' £47.50',
#  ' From £144.99',
#  ' £79.99',
#  ' £149.99',
#  ' £44.99',
#  ' £47.99',
#  ' £159.99',
#  ' £65.00',
#  ' £30.79',
#  ' £124.99',
#  ' £114.99',
#  ' £54.99',
#  ' £47.99',
#  ' £129.99',
#  ' £38.49',
#  ' From £38.39',
#  ' £10.79',
#  ' £17.99',
#  ' £55.24',
#  ' £19.19',
#  ' £38.49',
#  ' £55.99',
#  ' £47.99',
#  ' £87.49',
#  ' £114.99',
#  ' £114.99',
#  ' £47.99',
#  ' £76.99',
#  ' £69.99',
#  ' £104.99',
#  ' £64.99',
#  ' £41.99',
#  ' £73.49',
#  ' £55.99',
#  ' £90.99',
#  ' £50.99',
#  ' £54.99',
#  ' £64.99',
#  ' £54.99',
#  ' £75.99',
#  ' £23.99',
#  ' £55.99',
#  ' £79.99',
#  ' £48.99',
#  ' £112.49',
#  ' £103.49',
#  ' £93.74',
#  ' £94.99',
#  ' £64.99',
# ...

# %%
len(brand)
# Out:
# 84

# %%
len(price)
# Out:
# 84

# %%
price[80]
# Out:
# ' £54.99'

# %%
name[80]
# Out:
# 'DUMMY - Walking sandals - oracle aqua/laser orange/black/ghost green/white'

# %%
item_selector[0].select('img[src^="https://img01.ztat.net/article/spp-media-p1/"]')[0]["src"]
# Out:
# 'https://img01.ztat.net/article/spp-media-p1/1aab46d1ea293c138ae3fa88ac7ef423/972668ab9d6d4759b1425ab2189ddb13.jpg?imwidth=606&filter=packshot'

# %%
item_selector[0].select('img[src^="https://img01.ztat.net/article/spp-media-p1/"]')[0]["src"]

# %%
brand_nike = []
name_nike = []
price_nike = []
img_links_nike = []

# %%
# Nike webscraper

url_nike = 'https://www.zalando.co.uk/men/?q=nike+shoes&p='

for page in range(1,12):
    url_nike = 'https://www.zalando.co.uk/men/?q=nike+shoes&p='+str(page)
    browser = webdriver.Chrome(path)
    browser.get(url_nike)
    sleep(3)
    soup = BeautifulSoup(browser.page_source,'lxml')
    browser.close()
    item_selector = soup.select('.qMZa55.SQGpu8.iOzucJ.JT3_zV.DvypSJ')
    
    for img in x:
        img_links_nike.append(img['src'])

    for index, img_link in enumerate(img_links_nike):
        img_data = requests.get(img_link).content
        with open('sneakers pics/nike pics/'+str(index+1)+'.jpg', 'wb+') as f:
            f.write(img_data)

    for item in item_selector:
        x = soup.select('img[src^="https://img01.ztat.net/article/spp-media-p1/"]')
        try:
            brand_nike.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.uc9Eq5.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text)
            name_nike.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text)        
            price_nike.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.cMfkVL')[0].text)
        except:
            price_nike.append(item.select('.u-6V88.ka2E9k.uMhVZi.dgII7d.z-oVg8._88STHx.cMfkVL')[0].text)

# %%
len(brand_nike)
# Out:
# 924

# %%
len(name_nike)
# Out:
# 924

# %%
len(price_nike)
# Out:
# 924

# %%
nike = pd.DataFrame({'brand':brand_nike, 'name':name_nike, 'price':price_nike})

nike.head(5)
# Out:
#              brand                                               name  \
# 0  Nike Sportswear                 AIR FORCE 1 '07 - Trainers - black
# 1  Nike Sportswear  AIR MAX 2090 - Trainers - black/white/wolf gre...
# 2  Nike Sportswear     AIR FORCE 1 ’07 AN20  - Trainers - black/white
# 3  Nike Sportswear  AIR MAX 2090 - Trainers - white/black/wolf gre...
# 4  Nike Sportswear  AIR MAX 90 - Trainers - black/white/metallic s...
#
#       price
# 0    £74.99
# 1    £77.99
# 2    £89.99
# 3    £65.00
# 4   £112.49

# %%
nike.to_csv('nike_shoes.csv')

# %%
nike['brand'].value_counts()
# Out:
# Nike Performance    529
# Nike Sportswear     318
# Nike SB              56
# Nike Golf            21
# Name: brand, dtype: int64

# %%
924 - 84
# Out:
# 840

# %%
nike.head(840)
# Out:
#                 brand                                               name  \
# 0     Nike Sportswear                 AIR FORCE 1 '07 - Trainers - black
# 1     Nike Sportswear  AIR MAX 2090 - Trainers - black/white/wolf gre...
# 2     Nike Sportswear     AIR FORCE 1 ’07 AN20  - Trainers - black/white
# 3     Nike Sportswear  AIR MAX 2090 - Trainers - white/black/wolf gre...
# 4     Nike Sportswear  AIR MAX 90 - Trainers - black/white/metallic s...
# ..                ...                                                ...
# 835         Nike Golf             AIR MAX 1 G - Golf shoes - white/black
# 836  Nike Performance  METCON 5 AMP - Trainers - black/fire pink/gree...
# 837   Nike Sportswear    BENASSI JDI - Pool slides - black/challenge red
# 838  Nike Performance  KYRIE FLYTRAP III - Basketball shoes - summit ...
# 839  Nike Performance  NIKECOURT AIR MAX WILDCARD - Multicourt tennis...
#
#         price
# 0      £74.99
# 1      £77.99
# 2      £89.99
# 3      £65.00
# ...

# %%
brand_adidas = []
name_adidas = []
price_adidas = []
img_links_adidas = []

# %%
# Adidas webscraper

url_adidas = 'https://www.zalando.co.uk/men/?q=adidas+shoes&p='

for page in range(1,14):
    url_adidas = 'https://www.zalando.co.uk/men/?q=adidas+shoes&p='+str(page)
    x = soup.select('img[src^="https://img01.ztat.net/article/spp-media-p1/"]')
    browser = webdriver.Chrome(path)
    browser.get(url_adidas)
    sleep(3)
    soup = BeautifulSoup(browser.page_source,'lxml')
    browser.close()
    item_selector = soup.select('.qMZa55.SQGpu8.iOzucJ.JT3_zV.DvypSJ')
    
    for img in x:
        img_links_adidas.append(img['src'])

    for index, img_link in enumerate(img_links_adidas):
        img_data = requests.get(img_link).content
        with open('sneakers pics/adidas pics/'+str(index+1)+'.jpg', 'wb+') as f:
            f.write(img_data)

    for item in item_selector:
        try:
            brand_adidas.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.uc9Eq5.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text)
            name_adidas.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.ZkIJC-.r9BRio.qXofat.EKabf7')[0].text)        
            price_adidas.append(item.select('.u-6V88.ka2E9k.uMhVZi.FxZV-M.z-oVg8.pVrzNP.cMfkVL')[0].text)
        except:
            price_adidas.append(item.select('.u-6V88.ka2E9k.uMhVZi.dgII7d.z-oVg8._88STHx.cMfkVL')[0].text)

# %%
len(brand_adidas)
# Out:
# 1092

# %%
len(name_adidas)
# Out:
# 1092

# %%
len(price_adidas)
# Out:
# 1092

# %%
adidas = pd.DataFrame({'brand':brand_adidas, 'name':name_adidas, 'price':price_adidas})

adidas.head(5)
# Out:
#                 brand                                               name  \
# 0    adidas Originals        PATH RUN UNISEX - Trainers - footwear white
# 1    adidas Originals  JEANS UNISEX - Trainers - footwear white/colle...
# 2    adidas Originals             ZX FLUX UNISEX - Trainers - core black
# 3  adidas Performance  SAMBA LEATHER FOOTBALL SHOES INDOOR - Trainers...
# 4    adidas Originals             OZWEEGO - Trainers - core black/carbon
#
#           price
# 0        £79.99
# 1        £89.99
# 2        £79.99
# 3        £46.74
# 4   From £62.99

# %%
adidas.to_csv('adidas_shoes.csv')

# %%
adidas['brand'].value_counts()
# Out:
# adidas Performance    563
# adidas Originals      514
# adidas Golf            15
# Name: brand, dtype: int64

# %%
adidas.head(5)
# Out:
#                 brand                                               name  \
# 0    adidas Originals        PATH RUN UNISEX - Trainers - footwear white
# 1    adidas Originals  JEANS UNISEX - Trainers - footwear white/colle...
# 2    adidas Originals             ZX FLUX UNISEX - Trainers - core black
# 3  adidas Performance  SAMBA LEATHER FOOTBALL SHOES INDOOR - Trainers...
# 4    adidas Originals             OZWEEGO - Trainers - core black/carbon
#
#           price
# 0        £79.99
# 1        £89.99
# 2        £79.99
# 3        £46.74
# 4   From £62.99

# %%
# webcam
# adidas & nike as a first approach
